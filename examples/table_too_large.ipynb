# %%
# %load_ext autoreload

# %%
# %autoreload 2
import pandas as pd
import fetcha as fetcha

# %%
# https://www.ssb.no/en/statbank/list/pasient

# %%
ssb = fetcha.SSB("10261")
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.

# %%
fltr = [{"code": "Region", "values": ["0"]}]

# %%
df = ssb.fetch(fltr=fltr)

# %%
ssb.pivot(df)
# Out:
# statistikkvariabel                                                                                                                 Antall dagbehandlinger  \
# region      kjønn       alder       diagnose: ICD-10-kapittel                          statistikkvariabel                    år
# Hele landet Begge kjønn 0-9 år      ANDRE OG UOPPGITTE ÅRSAKER TIL SYKEHUSOPPHOLD      Antall dagbehandlinger                2019                  2157.0
#                                                                                        Antall døgnopphold (utskrivninger)    2019                     NaN
#                                                                                        Antall liggedager                     2019                     NaN
#                                                                                        Antall polikliniske konsultasjoner    2019                     NaN
#                                                                                        Pasienter med dagbehandling           2019                     NaN
# ...                                                                                                                                                   ...
#             Menn        Alder i alt Ødem, proteinuri og kompl. som følge av hyperte... Antall polikliniske konsultasjoner    2019                     NaN
#                                                                                        Pasienter med dagbehandling           2019                     NaN
#                                                                                        Pasienter med døgnopphold             2019                     NaN
#                                                                                        Pasienter på poliklinikk              2019                     NaN
#                                                                                        Pasienter på somatiske sykehus totalt 2019                     NaN
#
# statistikkvariabel                                                                                                                 Antall døgnopphold (utskrivninger)  \
# region      kjønn       alder       diagnose: ICD-10-kapittel                          statistikkvariabel                    år
# Hele landet Begge kjønn 0-9 år      ANDRE OG UOPPGITTE ÅRSAKER TIL SYKEHUSOPPHOLD      Antall dagbehandlinger                2019                                 NaN
#                                                                                        Antall døgnopphold (utskrivninger)    2019                             50426.0
#                                                                                        Antall liggedager                     2019                                 NaN
#                                                                                        Antall polikliniske konsultasjoner    2019                                 NaN
#                                                                                        Pasienter med dagbehandling           2019                                 NaN
# ...                                                                                                                                                               ...
#             Menn        Alder i alt Ødem, proteinuri og kompl. som følge av hyperte... Antall polikliniske konsultasjoner    2019                                 NaN
#                                                                                        Pasienter med dagbehandling           2019                                 NaN
#                                                                                        Pasienter med døgnopphold             2019                                 NaN
#                                                                                        Pasienter på poliklinikk              2019                                 NaN
#                                                                                        Pasienter på somatiske sykehus totalt 2019                                 NaN
#
# statistikkvariabel                                                                                                                 Antall liggedager  \
# region      kjønn       alder       diagnose: ICD-10-kapittel                          statistikkvariabel                    år
# Hele landet Begge kjønn 0-9 år      ANDRE OG UOPPGITTE ÅRSAKER TIL SYKEHUSOPPHOLD      Antall dagbehandlinger                2019                NaN
#                                                                                        Antall døgnopphold (utskrivninger)    2019                NaN
#                                                                                        Antall liggedager                     2019           138897.0
#                                                                                        Antall polikliniske konsultasjoner    2019                NaN
#                                                                                        Pasienter med dagbehandling           2019                NaN
# ...                                                                                                                                              ...
#             Menn        Alder i alt Ødem, proteinuri og kompl. som følge av hyperte... Antall polikliniske konsultasjoner    2019                NaN
#                                                                                        Pasienter med dagbehandling           2019                NaN
#                                                                                        Pasienter med døgnopphold             2019                NaN
#                                                                                        Pasienter på poliklinikk              2019                NaN
#                                                                                        Pasienter på somatiske sykehus totalt 2019                NaN
#
# statistikkvariabel                                                                                                                 Antall polikliniske konsultasjoner  \
# region      kjønn       alder       diagnose: ICD-10-kapittel                          statistikkvariabel                    år
# Hele landet Begge kjønn 0-9 år      ANDRE OG UOPPGITTE ÅRSAKER TIL SYKEHUSOPPHOLD      Antall dagbehandlinger                2019                                 NaN
#                                                                                        Antall døgnopphold (utskrivninger)    2019                                 NaN
#                                                                                        Antall liggedager                     2019                                 NaN
#                                                                                        Antall polikliniske konsultasjoner    2019                             88218.0
#                                                                                        Pasienter med dagbehandling           2019                                 NaN
# ...                                                                                                                                                               ...
#             Menn        Alder i alt Ødem, proteinuri og kompl. som følge av hyperte... Antall polikliniske konsultasjoner    2019                                 0.0
#                                                                                        Pasienter med dagbehandling           2019                                 NaN
#                                                                                        Pasienter med døgnopphold             2019                                 NaN
#                                                                                        Pasienter på poliklinikk              2019                                 NaN
#                                                                                        Pasienter på somatiske sykehus totalt 2019                                 NaN
#
# statistikkvariabel                                                                                                                 Pasienter med dagbehandling  \
# region      kjønn       alder       diagnose: ICD-10-kapittel                          statistikkvariabel                    år
# Hele landet Begge kjønn 0-9 år      ANDRE OG UOPPGITTE ÅRSAKER TIL SYKEHUSOPPHOLD      Antall dagbehandlinger                2019                          NaN
#                                                                                        Antall døgnopphold (utskrivninger)    2019                          NaN
#                                                                                        Antall liggedager                     2019                          NaN
#                                                                                        Antall polikliniske konsultasjoner    2019                          NaN
#                                                                                        Pasienter med dagbehandling           2019                       2034.0
# ...                                                                                                                                                        ...
#             Menn        Alder i alt Ødem, proteinuri og kompl. som følge av hyperte... Antall polikliniske konsultasjoner    2019                          NaN
#                                                                                        Pasienter med dagbehandling           2019                          0.0
#                                                                                        Pasienter med døgnopphold             2019                          NaN
#                                                                                        Pasienter på poliklinikk              2019                          NaN
#                                                                                        Pasienter på somatiske sykehus totalt 2019                          NaN
#
# statistikkvariabel                                                                                                                 Pasienter med døgnopphold  \
# region      kjønn       alder       diagnose: ICD-10-kapittel                          statistikkvariabel                    år
# Hele landet Begge kjønn 0-9 år      ANDRE OG UOPPGITTE ÅRSAKER TIL SYKEHUSOPPHOLD      Antall dagbehandlinger                2019                        NaN
#                                                                                        Antall døgnopphold (utskrivninger)    2019                        NaN
#                                                                                        Antall liggedager                     2019                        NaN
#                                                                                        Antall polikliniske konsultasjoner    2019                        NaN
#                                                                                        Pasienter med dagbehandling           2019                        NaN
# ...                                                                                                                                                      ...
#             Menn        Alder i alt Ødem, proteinuri og kompl. som følge av hyperte... Antall polikliniske konsultasjoner    2019                        NaN
#                                                                                        Pasienter med dagbehandling           2019                        NaN
#                                                                                        Pasienter med døgnopphold             2019                        0.0
#                                                                                        Pasienter på poliklinikk              2019                        NaN
#                                                                                        Pasienter på somatiske sykehus totalt 2019                        NaN
#
# statistikkvariabel                                                                                                                 Pasienter på poliklinikk  \
# region      kjønn       alder       diagnose: ICD-10-kapittel                          statistikkvariabel                    år
# Hele landet Begge kjønn 0-9 år      ANDRE OG UOPPGITTE ÅRSAKER TIL SYKEHUSOPPHOLD      Antall dagbehandlinger                2019                       NaN
#                                                                                        Antall døgnopphold (utskrivninger)    2019                       NaN
#                                                                                        Antall liggedager                     2019                       NaN
#                                                                                        Antall polikliniske konsultasjoner    2019                       NaN
#                                                                                        Pasienter med dagbehandling           2019                       NaN
# ...                                                                                                                                                     ...
#             Menn        Alder i alt Ødem, proteinuri og kompl. som følge av hyperte... Antall polikliniske konsultasjoner    2019                       NaN
#                                                                                        Pasienter med dagbehandling           2019                       NaN
#                                                                                        Pasienter med døgnopphold             2019                       NaN
#                                                                                        Pasienter på poliklinikk              2019                       0.0
#                                                                                        Pasienter på somatiske sykehus totalt 2019                       NaN
#
# statistikkvariabel                                                                                                                 Pasienter på somatiske sykehus totalt
# region      kjønn       alder       diagnose: ICD-10-kapittel                          statistikkvariabel                    år
# Hele landet Begge kjønn 0-9 år      ANDRE OG UOPPGITTE ÅRSAKER TIL SYKEHUSOPPHOLD      Antall dagbehandlinger                2019                                    NaN
#                                                                                        Antall døgnopphold (utskrivninger)    2019                                    NaN
#                                                                                        Antall liggedager                     2019                                    NaN
#                                                                                        Antall polikliniske konsultasjoner    2019                                    NaN
#                                                                                        Pasienter med dagbehandling           2019                                    NaN
# ...                                                                                                                                                                  ...
#             Menn        Alder i alt Ødem, proteinuri og kompl. som følge av hyperte... Antall polikliniske konsultasjoner    2019                                    NaN
#                                                                                        Pasienter med dagbehandling           2019                                    NaN
#                                                                                        Pasienter med døgnopphold             2019                                    NaN
#                                                                                        Pasienter på poliklinikk              2019                                    NaN
#                                                                                        Pasienter på somatiske sykehus totalt 2019                                    0.0
#
# [17856 rows x 8 columns]
